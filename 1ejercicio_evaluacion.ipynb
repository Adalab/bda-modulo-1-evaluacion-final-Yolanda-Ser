# %%
class Producto:                                                         # Estructura de la clase con sus atributos. CONSTRUCTOR
    def __init__(self, nombre, precio, cantidad):                       # Esta clase es la que maneja los productos 
        self.nombre = nombre
        self.precio = precio
        self.cantidad = cantidad



class TiendaOnline:
    def __init__(self):
        self.inventario = []                                          #  Esta clase es la que tiene el inventario
        self.clientes = {}
        ventas_totales = 0.0
    
    def agregar_producto(self, nombre, precio, cantidad):
        nuevo_producto = {"nombre" : nombre, "precio": precio, "cantidad" : cantidad}
        
        for producto in self.inventario:
            if producto['nombre'] == nombre:
                producto['cantidad'] += cantidad
            else:
                self.inventario.append(nuevo_producto)

    def ver_inventario(self):
        for producto in self.inventario:
           print(f"nombre: {producto['nombre']}, Precio: {producto['precio']}, Cantidad: {producto['cantidad']}")

    def buscar_producto(self, nombre):
        for producto in self.inventario:
            if producto['nombre'] == nombre:
                print(f"Nombre: {producto['nombre']}, Precio: ${producto['precio']}, Cantidad: {producto['cantidad']}")
                return
        print(f"Producto '{nombre}' no encontrado en el inventario.")

    def actualizar_stock(self, nombre,cantidad):
        for producto in self.inventario:
            if producto['nombre'] == nombre:
                producto['cantidad'] += cantidad
                return
            

# eliminar un producto  PENDIENTE   
    
    def calcular_valor_inventario(self):
        valor_total = sum(producto['precio'] * producto['cantidad'] for producto in self.inventario)
        print(f"Valor total del inventario:{valor_total}")
        
# realizar compra (self pendiente 
# procesar_pago (self) pendiente 

    def agregar_cliente(self, nombre, email):
        if nombre not in self.clientes:
            self.clientes[nombre] = {'email': email, 'compras': []}
        

    def ver_clientes(self):
        for nombre  in self.clientes.items():
            print("nombre: {nombre}, Email: {email}")

#registrar compra(self,nombre,cliente,carrito):
# ver compras_cliente(self,nombre_cliente):
